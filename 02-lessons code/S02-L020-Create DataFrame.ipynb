# %% [markdown]
# # Create a DataFrame

# %%
from pyspark.sql import SparkSession

spark = SparkSession.builder.appName("myApp").master("local[*]").getOrCreate()

# %% [markdown]
# Data Frame can be initiated with variables

# %%
data = [
["Po",652,True,"Turin, Piacenza, Ferrara, Rovigo","Adriatic Sea",123],
["Tiber",405,True,"Rome, Terni","Tyrrhenian Sea",66],
["Arno",241,True,"Florence, Pisa","Ligurian Sea",40],
["Adda",313,False,"Lecco, Milan","Po River",63],
["Piave",220,True,"Belluno, Treviso","Adriatic Sea",19],
["Adige",410,True,"Verona, Trento","Adriatic Sea",105],
["Reno",211,True,"Bologna, Ferrara","Adriatic Sea",25],
["Isonzo",136,False,"Gorizia, Monfalcone","Adriatic Sea",18],
["Brenta",174,True,"Bassano del Grappa, Padua","Adriatic Sea",37],
["Savio",126,True,"Cesena, Ravenna","Adriatic Sea",12],
["Tagliamento",170,True,"Udine, Latisana","Adriatic Sea",22],
["Liri",158,True,"Sora, Cassino","Tyrrhenian Sea",15],
["Volturno",175,True,"Capua, Castel Volturno","Tyrrhenian Sea",30],
["Sele",64,True,"Eboli, Paestum","Tyrrhenian Sea",10],
["Tanaro",276,True,"Alessandria, Asti","Po River",45],
["Trebbia",115,True,"Piacenza, Bobbio","Po River",20],
["Serchio",111,True,"Lucca, Pisa","Ligurian Sea",18],
["Sieve",62,True,"Florence, Pontassieve","Arno River",8],
["Ombrone",161,True,"Grosseto, Siena","Tyrrhenian Sea",14],
["Chiana",42,True,"Arezzo, Chiusi","Arno River",5],
["Magra",62,True,"Pontremoli, Aulla","Ligurian Sea",7],
["Cecina",73,True,"Volterra, Cecina","Tyrrhenian Sea",9],
["Cornia",50,True,"Massa Marittima, Piombino","Tyrrhenian Sea",6],
["Fiora",80,True,"Montalto di Castro, Canino","Tyrrhenian Sea",11],
["Marta",52,True,"Tuscania, Tarquinia","Tyrrhenian Sea",7],
["Paglia",86,True,"Orvieto, Acquapendente","Tiber River",12],
["Nera",116,True,"Terni, Narni","Tiber River",15],
["Velino",90,True,"Rieti, Antrodoco","Nera River",10],
["Aniene",99,True,"Subiaco, Tivoli","Tiber River",13],
["Sacco",87,True,"Frosinone, Ceccano","Liri River",9],
["Garigliano",38,True,"Formia, Minturno","Tyrrhenian Sea",5],
["Trigno",85,True,"San Salvo, Vasto","Adriatic Sea",8],
["Biferno",84,True,"Campobasso, Termoli","Adriatic Sea",10],
["Fortore",110,True,"San Severo, Lucera","Adriatic Sea",12],
["Ofanto",170,True,"Canosa di Puglia, Barletta","Adriatic Sea",20],
["Basento",149,True,"Potenza, Matera","Ionian Sea",18],
["Agri",136,True,"Policoro, Tursi","Ionian Sea",14],
["Sinni",94,True,"Senise, Rotondella","Ionian Sea",10],
["Bradano",120,True,"Matera, Ginosa","Ionian Sea",12],
["Cavone",60,True,"Pisticci, Scanzano Jonico","Ionian Sea",6],
["Crati",91,True,"Cosenza, Corigliano-Rossano","Ionian Sea",11],
["Neto",90,True,"Crotone, Strongoli","Ionian Sea",10],
["Tacina",58,True,"Catanzaro, Botricello","Ionian Sea",7],
["Amato",59,True,"Lamezia Terme, Nicastro","Tyrrhenian Sea",8],
["Savuto",48,True,"Rogliano, Amantea","Tyrrhenian Sea",6],
["Lao",51,True,"Scalea, Papasidero","Tyrrhenian Sea",7],
["Noce",105,True,"Maratea, Trecchina","Tyrrhenian Sea",9],
["Tanagro",92,True,"Sala Consilina, Polla","Sele River",10],
["Calore Irpino",108,True,"Benevento, Avellino","Volturno River",12],
["Aterno-Pescara",152,True,"Pescara, Chieti","Adriatic Sea",20],
["Bacchiglione",118,True,"Vicenza, Padua","Adriatic Sea",15],
["Bormida",154,True,"Acqui Terme, Alessandria","Po River",18],
["Chienti",91,True,"Macerata, Civitanova Marche","Adriatic Sea",10],
["Esino",85,True,"Jesi, Ancona","Adriatic Sea",12],
["Fiume",115,True,"Fiume Veneto, Pordenone","Adriatic Sea",14],
["Lambro",130,True,"Monza, Milan","Po River",22],
["Mincio",75,True,"Mantua, Peschiera del Garda","Po River",9],
["Natisone",60,False,"Cividale del Friuli, Udine","Adriatic Sea",8],
["Oglio",280,True,"Brescia, Cremona","Po River",30],
["Piomba",55,True,"Pescara, Montesilvano","Adriatic Sea",7],
["Rubicon",80,True,"Cesena, Rimini","Adriatic Sea",10],
["Sangro",117,True,"Lanciano, Atessa","Adriatic Sea",12],
["Secchia",172,True,"Modena, Reggio Emilia","Po River",20],
["Serio",124,True,"Bergamo, Crema","Po River",15],
["Simeto",113,True,"Catania, Paternò","Ionian Sea",14],
["Sillaro",66,True,"Imola, Castel San Pietro Terme","Adriatic Sea",8],
["Stura di Demonte",115,True,"Cuneo, Fossano","Po River",12],
["Taro",126,True,"Parma, Fornovo di Taro","Po River",15],
["Ticino",248,False,"Pavia, Vigevano","Po River",25],
["Trebbia",115,True,"Piacenza, Bobbio","Po River",20],
["Vara",58,True,"La Spezia, Brugnato","Ligurian Sea",7],
["Vibrata",65,True,"Alba Adriatica, Corropoli","Adriatic Sea",8]
]

schema = "name string, length int, one_country boolean, cities string, sea string, number_bricks int"

# %% [markdown]
# When creating a DataFrame, we can define the schema

# %%
spark.createDataFrame?

# %%
rivers = spark.createDataFrame(data = data, schema = schema)

# %% [markdown]
# Internally DataFrames are implemented using Resilient Distributed Dataset (RDD)

# %%
rivers.rdd.getNumPartitions()
# Out:
# 2

# %% [markdown]
# Default number of partitions depends on the number of cores used by Spark

# %%
conf = spark.sparkContext.getConf()
conf.get("spark.executor.memory", "unknown")
# Out:
# 'unknown'

# %%
print(spark.sparkContext.getConf().getAll())
# Out:
# [('spark.driver.extraJavaOptions', '-Djava.net.preferIPv6Addresses=false -XX:+IgnoreUnrecognizedVMOptions --add-opens=java.base/java.lang=ALL-UNNAMED --add-opens=java.base/java.lang.invoke=ALL-UNNAMED --add-opens=java.base/java.lang.reflect=ALL-UNNAMED --add-opens=java.base/java.io=ALL-UNNAMED --add-opens=java.base/java.net=ALL-UNNAMED --add-opens=java.base/java.nio=ALL-UNNAMED --add-opens=java.base/java.util=ALL-UNNAMED --add-opens=java.base/java.util.concurrent=ALL-UNNAMED --add-opens=java.base/java.util.concurrent.atomic=ALL-UNNAMED --add-opens=java.base/jdk.internal.ref=ALL-UNNAMED --add-opens=java.base/sun.nio.ch=ALL-UNNAMED --add-opens=java.base/sun.nio.cs=ALL-UNNAMED --add-opens=java.base/sun.security.action=ALL-UNNAMED --add-opens=java.base/sun.util.calendar=ALL-UNNAMED --add-opens=java.security.jgss/sun.security.krb5=ALL-UNNAMED -Djdk.reflect.useDirectMethodHandle=false'), ('spark.app.name', 'myApp'), ('spark.app.startTime', '1746027173126'), ('spark.executor.id', 'driver'), ('spark.sql.warehouse.dir', 'file:/content/spark-warehouse'), ('spark.driver.port', '37573'), ('spark.driver.host', '839be55ac637'), ('spark.app.submitTime', '1746027172808'), ('spark.rdd.compress', 'True'), ('spark.executor.extraJavaOptions', '-Djava.net.preferIPv6Addresses=false -XX:+IgnoreUnrecognizedVMOptions --add-opens=java.base/java.lang=ALL-UNNAMED --add-opens=java.base/java.lang.invoke=ALL-UNNAMED --add-opens=java.base/java.lang.reflect=ALL-UNNAMED --add-opens=java.base/java.io=ALL-UNNAMED --add-opens=java.base/java.net=ALL-UNNAMED --add-opens=java.base/java.nio=ALL-UNNAMED --add-opens=java.base/java.util=ALL-UNNAMED --add-opens=java.base/java.util.concurrent=ALL-UNNAMED --add-opens=java.base/java.util.concurrent.atomic=ALL-UNNAMED --add-opens=java.base/jdk.internal.ref=ALL-UNNAMED --add-opens=java.base/sun.nio.ch=ALL-UNNAMED --add-opens=java.base/sun.nio.cs=ALL-UNNAMED --add-opens=java.base/sun.security.action=ALL-UNNAMED --add-opens=java.base/sun.util.calendar=ALL-UNNAMED --add-opens=java.security.jgss/sun.security.krb5=ALL-UNNAMED -Djdk.reflect.useDirectMethodHandle=false'), ('spark.serializer.objectStreamReset', '100'), ('spark.master', 'local[*]'), ('spark.submit.pyFiles', ''), ('spark.submit.deployMode', 'client'), ('spark.ui.showConsoleProgress', 'true'), ('spark.app.id', 'local-1746027175950')]

# %% [markdown]
# Data Frame transformations are lazy. They are executed first when action is called.

# %%
rivers.show()
# Out:
# +-----------+------+-----------+--------------------+--------------+-------------+
# |       name|length|one_country|              cities|           sea|number_bricks|
# +-----------+------+-----------+--------------------+--------------+-------------+
# |         Po|   652|       true|Turin, Piacenza, ...|  Adriatic Sea|          123|
# |      Tiber|   405|       true|         Rome, Terni|Tyrrhenian Sea|           66|
# |       Arno|   241|       true|      Florence, Pisa|  Ligurian Sea|           40|
# |       Adda|   313|      false|        Lecco, Milan|      Po River|           63|
# |      Piave|   220|       true|    Belluno, Treviso|  Adriatic Sea|           19|
# |      Adige|   410|       true|      Verona, Trento|  Adriatic Sea|          105|
# |       Reno|   211|       true|    Bologna, Ferrara|  Adriatic Sea|           25|
# |     Isonzo|   136|      false| Gorizia, Monfalcone|  Adriatic Sea|           18|
# |     Brenta|   174|       true|Bassano del Grapp...|  Adriatic Sea|           37|
# |      Savio|   126|       true|     Cesena, Ravenna|  Adriatic Sea|           12|
# |Tagliamento|   170|       true|     Udine, Latisana|  Adriatic Sea|           22|
# |       Liri|   158|       true|       Sora, Cassino|Tyrrhenian Sea|           15|
# |   Volturno|   175|       true|Capua, Castel Vol...|Tyrrhenian Sea|           30|
# |       Sele|    64|       true|      Eboli, Paestum|Tyrrhenian Sea|           10|
# |     Tanaro|   276|       true|   Alessandria, Asti|      Po River|           45|
# |    Trebbia|   115|       true|    Piacenza, Bobbio|      Po River|           20|
# |    Serchio|   111|       true|         Lucca, Pisa|  Ligurian Sea|           18|
# |      Sieve|    62|       true|Florence, Pontass...|    Arno River|            8|
# |    Ombrone|   161|       true|     Grosseto, Siena|Tyrrhenian Sea|           14|
# |     Chiana|    42|       true|      Arezzo, Chiusi|    Arno River|            5|
# +-----------+------+-----------+--------------------+--------------+-------------+
# only showing top 20 rows

# %% [markdown]
# DataFrames are immutable

# %%
rivers.where("length > 200").show()
# Out:
# +------+------+-----------+--------------------+--------------+-------------+
# |  name|length|one_country|              cities|           sea|number_bricks|
# +------+------+-----------+--------------------+--------------+-------------+
# |    Po|   652|       true|Turin, Piacenza, ...|  Adriatic Sea|          123|
# | Tiber|   405|       true|         Rome, Terni|Tyrrhenian Sea|           66|
# |  Arno|   241|       true|      Florence, Pisa|  Ligurian Sea|           40|
# |  Adda|   313|      false|        Lecco, Milan|      Po River|           63|
# | Piave|   220|       true|    Belluno, Treviso|  Adriatic Sea|           19|
# | Adige|   410|       true|      Verona, Trento|  Adriatic Sea|          105|
# |  Reno|   211|       true|    Bologna, Ferrara|  Adriatic Sea|           25|
# |Tanaro|   276|       true|   Alessandria, Asti|      Po River|           45|
# | Oglio|   280|       true|    Brescia, Cremona|      Po River|           30|
# |Ticino|   248|      false|     Pavia, Vigevano|      Po River|           25|
# +------+------+-----------+--------------------+--------------+-------------+

# %%
rivers.count()
# Out:
# 72

# %%
long_rivers = rivers.where("length > 200")

# %%
long_rivers.show()
# Out:
# +------+------+-----------+--------------------+--------------+-------------+
# |  name|length|one_country|              cities|           sea|number_bricks|
# +------+------+-----------+--------------------+--------------+-------------+
# |    Po|   652|       true|Turin, Piacenza, ...|  Adriatic Sea|          123|
# | Tiber|   405|       true|         Rome, Terni|Tyrrhenian Sea|           66|
# |  Arno|   241|       true|      Florence, Pisa|  Ligurian Sea|           40|
# |  Adda|   313|      false|        Lecco, Milan|      Po River|           63|
# | Piave|   220|       true|    Belluno, Treviso|  Adriatic Sea|           19|
# | Adige|   410|       true|      Verona, Trento|  Adriatic Sea|          105|
# |  Reno|   211|       true|    Bologna, Ferrara|  Adriatic Sea|           25|
# |Tanaro|   276|       true|   Alessandria, Asti|      Po River|           45|
# | Oglio|   280|       true|    Brescia, Cremona|      Po River|           30|
# |Ticino|   248|      false|     Pavia, Vigevano|      Po River|           25|
# +------+------+-----------+--------------------+--------------+-------------+

# %%
long_rivers.count()
# Out:
# 10

# %%
long_rivers.rdd.getNumPartitions()
# Out:
# 2

# %% [markdown]
# Saving the DataFrame to a file

# %%
long_rivers. \
  write. \
  format("csv"). \
  option("header", "true"). \
  mode("overwrite"). \
  save("long_rivers_1.csv")

# %%
long_rivers. \
  write.\
  csv("long_rivers_2.csv", header=True, mode="overwrite")

# %% [markdown]
# Trick - convert to Pandas

# %%
long_rivers.toPandas().to_csv("long_rivers_true_csv.csv", sep=',', header=True, index=False)

# %% [markdown]
# Trick - use OS methods

# %%
! ls -l
# Out:
# total 16
# drwxr-xr-x 2 root root 4096 Apr 30 15:33 long_rivers_1.csv
# drwxr-xr-x 2 root root 4096 Apr 30 15:33 long_rivers_2.csv
# -rw-r--r-- 1 root root  538 Apr 30 15:33 long_rivers_true_csv.csv
# drwxr-xr-x 1 root root 4096 Apr 28 13:35 sample_data

# %% [markdown]
# Trick - use Python methods

# %%
import os

print(os.listdir())
# Out:
# ['.config', 'long_rivers_2.csv', 'long_rivers_true_csv.csv', 'long_rivers_1.csv', 'sample_data']
